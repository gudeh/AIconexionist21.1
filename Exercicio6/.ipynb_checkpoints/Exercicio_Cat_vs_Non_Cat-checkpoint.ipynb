# %%
import os

import pandas as pd
import numpy as np
import math
import itertools

import h5py

from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam


import matplotlib.pyplot as plt
import seaborn as sns

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
IMAGE_SIZE = 256
# IMAGE_DIRECTORY = './gdrive/MyDrive/Jupyter Programs/Datasets/'
IMAGE_DIRECTORY = './'

# %%
filename = 'train_catvnoncat.h5'
f = h5py.File(IMAGE_DIRECTORY+filename, 'r')

# %%
list(f.keys())
# Out:
# ['list_classes', 'train_set_x', 'train_set_y']

# %%
data_train = list(f['train_set_x'])
data_label = list(f['train_set_y'])
print(len(data_train))
# Out:
# 209

# %%
X_tr=np.array(data_train)
y_tr= np.array(data_label)

# %%
filename = 'test_catvnoncat.h5'
f = h5py.File(IMAGE_DIRECTORY+filename, 'r')

# %%
list(f.keys())
# Out:
# ['list_classes', 'test_set_x', 'test_set_y']

# %%
data_test = list(f['test_set_x'])
data_label_test = list(f['test_set_y'])
print(len(data_test))
# Out:
# 50

# %%
X_test=np.array(data_test)
y_test= np.array(data_label_test)

# %% [markdown]
# # Mostrando alguns exemplos de imagens

# %%
print(data_train[1].shape)
n=20
plt.figure(figsize=(15, 15))
for i in range(n):
    ax = plt.subplot(4, 5, i + 1)
    plt.imshow(data_train[i+10])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
# Out:
# (64, 64, 3)

# %% [markdown]
# # Visualizando se as classes estao razoavelmente balanceadas

# %%
sns.set_style('darkgrid')
sns.countplot(y_tr,palette='twilight')
# Out:
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# # Separando os dados em Treinamento e Validacao

# %%
X_train,X_val,Y_train,Y_val = train_test_split(X_tr,y_tr,test_size = 0.1)
print('Shape of train set feature',X_train.shape)
print('Shape of validation set feature',X_val.shape)
print('Shape of train set label',Y_train.shape)
print('Shape of validation set label',Y_val.shape)

num_classes=2
input_shape = (64,64,3)

Y_train = to_categorical(Y_train, num_classes)
Y_val = to_categorical(Y_val, num_classes)
Y_test = to_categorical(y_test, num_classes)
# Out:
# Shape of train set feature (188, 64, 64, 3)
# Shape of validation set feature (21, 64, 64, 3)
# Shape of train set label (188,)
# Shape of validation set label (21,)

# %%
print(input_shape)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="selu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="selu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(128, kernel_size=(3, 3), activation="selu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="selu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="sigmoid"),
    ]
)
# Out:
# (64, 64, 3)

# %%
lr=0.001

# Compile the model.
model.compile(
  optimizer=Adam(learning_rate=lr),
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)
model.summary()
# from keras.utils.vis_utils import plot_model
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 64)          73792
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 514
# =================================================================
# Total params: 167,554
# Trainable params: 167,554
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train,validation_data = (X_val, Y_val),epochs=150, batch_size=64)
# Out:
# Epoch 1/150
# 3/3 [==============================] - 2s 684ms/step - loss: 17.6881 - accuracy: 0.5518 - val_loss: 3.2043 - val_accuracy: 0.7619
# Epoch 2/150
# 3/3 [==============================] - 1s 212ms/step - loss: 8.1979 - accuracy: 0.5958 - val_loss: 1.9896 - val_accuracy: 0.4762
# Epoch 3/150
# 3/3 [==============================] - 1s 210ms/step - loss: 3.3694 - accuracy: 0.5149 - val_loss: 1.0161 - val_accuracy: 0.7143
# Epoch 4/150
# 3/3 [==============================] - 1s 212ms/step - loss: 1.8792 - accuracy: 0.6467 - val_loss: 1.2177 - val_accuracy: 0.5714
150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0971 - accuracy: 0.9672 - val_loss: 1.3613 - val_accuracy: 0.8095
# Epoch 76/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0521 - accuracy: 0.9783 - val_loss: 1.4408 - val_accuracy: 0.7143
# Epoch 77/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.1408 - accuracy: 0.9606 - val_loss: 1.3222 - val_accuracy: 0.8095
# Epoch 78/150
# 3/3 [==============================] - 1s 226ms/step - loss: 0.1082 - accuracy: 0.9711 - val_loss: 0.9462 - val_accuracy: 0.8095
# Epoch 79/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0465 - accuracy: 0.9691 - val_loss: 0.8369 - val_accuracy: 0.7619
# Epoch 80/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0125 - accuracy: 0.9915 - val_loss: 0.6603 - val_accuracy: 0.8095
# Epoch 81/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0105 - accuracy: 0.9908 - val_loss: 0.5467 - val_accuracy: 0.8571
# Epoch 82/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.4351 - val_accuracy: 0.8571
# Epoch 83/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4446 - val_accuracy: 0.9048
# Epoch 84/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.0710 - val_accuracy: 0.7619
# Epoch 85/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.1282 - accuracy: 0.9757 - val_loss: 1.1593 - val_accuracy: 0.7143
# Epoch 86/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0723 - accuracy: 0.9638 - val_loss: 0.5578 - val_accuracy: 0.8571
# Epoch 87/150
# 3/3 [==============================] - 1s 232ms/step - loss: 0.0215 - accuracy: 0.9855 - val_loss: 1.1539 - val_accuracy: 0.8571
# Epoch 88/150
# 3/3 [==============================] - 1s 246ms/step - loss: 0.1302 - accuracy: 0.9711 - val_loss: 0.8112 - val_accuracy: 0.7619
# Epoch 89/150
# 3/3 [==============================] - 1s 242ms/step - loss: 0.0849 - accuracy: 0.9709 - val_loss: 0.9944 - val_accuracy: 0.7143
# Epoch 90/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0593 - accuracy: 0.9789 - val_loss: 1.5595 - val_accuracy: 0.8095
# Epoch 91/150
# 3/3 [==============================] - 1s 232ms/step - loss: 0.0114 - accuracy: 0.9954 - val_loss: 1.2190 - val_accuracy: 0.8571
# Epoch 92/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0460 - accuracy: 0.9842 - val_loss: 1.0543 - val_accuracy: 0.7619
# Epoch 93/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0131 - accuracy: 0.9954 - val_loss: 1.2494 - val_accuracy: 0.8571
# Epoch 94/150
# 3/3 [==============================] - 1s 244ms/step - loss: 0.0108 - accuracy: 0.9954 - val_loss: 1.2629 - val_accuracy: 0.8571
# Epoch 95/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0126 - accuracy: 0.9927 - val_loss: 1.1089 - val_accuracy: 0.8571
# Epoch 96/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0139 - accuracy: 0.9915 - val_loss: 1.3282 - val_accuracy: 0.8571
# Epoch 97/150
# 3/3 [==============================] - 1s 231ms/step - loss: 0.0120 - accuracy: 0.9954 - val_loss: 1.0343 - val_accuracy: 0.8571
# Epoch 98/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0099 - accuracy: 0.9954 - val_loss: 0.6466 - val_accuracy: 0.8095
# Epoch 99/150
# 3/3 [==============================] - 1s 231ms/step - loss: 0.0128 - accuracy: 0.9927 - val_loss: 0.8019 - val_accuracy: 0.8571
# Epoch 100/150
# 3/3 [==============================] - 1s 243ms/step - loss: 0.0097 - accuracy: 0.9954 - val_loss: 1.0022 - val_accuracy: 0.8571
# Epoch 101/150
# 3/3 [==============================] - 1s 249ms/step - loss: 0.0294 - accuracy: 0.9869 - val_loss: 0.6849 - val_accuracy: 0.7619
# Epoch 102/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0362 - accuracy: 0.9830 - val_loss: 0.6724 - val_accuracy: 0.7619
# Epoch 103/150
# 3/3 [==============================] - 1s 279ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.7282 - val_accuracy: 0.7619
# Epoch 104/150
# 3/3 [==============================] - 1s 244ms/step - loss: 0.0051 - accuracy: 0.9954 - val_loss: 0.7256 - val_accuracy: 0.8571
# Epoch 105/150
# 3/3 [==============================] - 1s 242ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.6710 - val_accuracy: 0.7619
# Epoch 106/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.6830 - val_accuracy: 0.7619
# Epoch 107/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0088 - accuracy: 0.9954 - val_loss: 0.7881 - val_accuracy: 0.7619
# Epoch 108/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0227 - accuracy: 0.9869 - val_loss: 0.7111 - val_accuracy: 0.8571
# Epoch 109/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0392 - accuracy: 0.9869 - val_loss: 1.7052 - val_accuracy: 0.8095
# Epoch 110/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.1501 - accuracy: 0.9652 - val_loss: 0.3147 - val_accuracy: 0.8095
# Epoch 111/150
# 3/3 [==============================] - 1s 232ms/step - loss: 0.0098 - accuracy: 0.9954 - val_loss: 0.9879 - val_accuracy: 0.7143
# Epoch 112/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0493 - accuracy: 0.9750 - val_loss: 0.3154 - val_accuracy: 0.9048
# Epoch 113/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0293 - accuracy: 0.9874 - val_loss: 0.5763 - val_accuracy: 0.9048
# Epoch 114/150
# 3/3 [==============================] - 1s 242ms/step - loss: 0.0157 - accuracy: 0.9947 - val_loss: 1.2518 - val_accuracy: 0.8095
# Epoch 115/150
# 3/3 [==============================] - 1s 230ms/step - loss: 0.0334 - accuracy: 0.9830 - val_loss: 1.3299 - val_accuracy: 0.7619
# Epoch 116/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0713 - accuracy: 0.9776 - val_loss: 1.0536 - val_accuracy: 0.7619
# Epoch 117/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0112 - accuracy: 0.9915 - val_loss: 0.8073 - val_accuracy: 0.8095
# Epoch 118/150
# 3/3 [==============================] - 1s 232ms/step - loss: 0.0334 - accuracy: 0.9927 - val_loss: 0.8297 - val_accuracy: 0.8571
# Epoch 119/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0195 - accuracy: 0.9874 - val_loss: 0.8923 - val_accuracy: 0.8571
# Epoch 120/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0815 - accuracy: 0.9776 - val_loss: 1.0488 - val_accuracy: 0.8571
# Epoch 121/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0200 - accuracy: 0.9927 - val_loss: 0.7674 - val_accuracy: 0.8571
# Epoch 122/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.8073 - val_accuracy: 0.7619
# Epoch 123/150
# 3/3 [==============================] - 1s 230ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.7150 - val_accuracy: 0.8095
# Epoch 124/150
# 3/3 [==============================] - 1s 226ms/step - loss: 0.0434 - accuracy: 0.9915 - val_loss: 0.7653 - val_accuracy: 0.7619
# Epoch 125/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0154 - accuracy: 0.9927 - val_loss: 0.8374 - val_accuracy: 0.8095
# Epoch 126/150
# 3/3 [==============================] - 1s 232ms/step - loss: 0.0185 - accuracy: 0.9954 - val_loss: 1.0071 - val_accuracy: 0.8095
# Epoch 127/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0321 - accuracy: 0.9823 - val_loss: 0.6443 - val_accuracy: 0.8571
# Epoch 128/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0213 - accuracy: 0.9927 - val_loss: 0.7159 - val_accuracy: 0.8095
# Epoch 129/150
# 3/3 [==============================] - 1s 230ms/step - loss: 2.9796e-04 - accuracy: 1.0000 - val_loss: 0.5836 - val_accuracy: 0.9048
# Epoch 130/150
# 3/3 [==============================] - 1s 234ms/step - loss: 9.7537e-04 - accuracy: 1.0000 - val_loss: 0.5858 - val_accuracy: 0.8095
# Epoch 131/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6089 - val_accuracy: 0.8095
# Epoch 132/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.6354 - val_accuracy: 0.8571
# Epoch 133/150
# 3/3 [==============================] - 1s 250ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.7784 - val_accuracy: 0.8095
# Epoch 134/150
# 3/3 [==============================] - 1s 282ms/step - loss: 0.0849 - accuracy: 0.9869 - val_loss: 1.3633 - val_accuracy: 0.7619
# Epoch 135/150
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0340 - accuracy: 0.9862 - val_loss: 0.6264 - val_accuracy: 0.8571
# Epoch 136/150
# 3/3 [==============================] - 1s 292ms/step - loss: 0.0181 - accuracy: 0.9927 - val_loss: 1.4015 - val_accuracy: 0.8095
# Epoch 137/150
# 3/3 [==============================] - 1s 322ms/step - loss: 0.0617 - accuracy: 0.9652 - val_loss: 0.3955 - val_accuracy: 0.8571
# Epoch 138/150
# 3/3 [==============================] - 1s 242ms/step - loss: 0.0223 - accuracy: 0.9803 - val_loss: 0.5116 - val_accuracy: 0.8571
# Epoch 139/150
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0146 - accuracy: 0.9947 - val_loss: 0.4920 - val_accuracy: 0.9048
# Epoch 140/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0191 - accuracy: 0.9915 - val_loss: 0.2191 - val_accuracy: 0.9048
# Epoch 141/150
# 3/3 [==============================] - 1s 280ms/step - loss: 0.0230 - accuracy: 0.9915 - val_loss: 0.3697 - val_accuracy: 0.9048
# Epoch 142/150
# 3/3 [==============================] - 1s 288ms/step - loss: 0.0112 - accuracy: 0.9915 - val_loss: 0.2811 - val_accuracy: 0.8571
# Epoch 143/150
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3439 - val_accuracy: 0.9048
# Epoch 144/150
# 3/3 [==============================] - 1s 292ms/step - loss: 0.0028 - accuracy: 0.9973 - val_loss: 0.4025 - val_accuracy: 0.8571
# Epoch 145/150
# 3/3 [==============================] - 1s 266ms/step - loss: 1.4452e-04 - accuracy: 1.0000 - val_loss: 0.4275 - val_accuracy: 0.8571
# Epoch 146/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5162 - val_accuracy: 0.8571
# Epoch 147/150
# 3/3 [==============================] - 1s 248ms/step - loss: 2.0193e-04 - accuracy: 1.0000 - val_loss: 0.6230 - val_accuracy: 0.8095
# Epoch 148/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.7005 - val_accuracy: 0.8095
# Epoch 149/150
# 3/3 [==============================] - 1s 252ms/step - loss: 0.0228 - accuracy: 0.9915 - val_loss: 0.5993 - val_accuracy: 0.8095
# Epoch 150/150
# 3/3 [==============================] - 1s 248ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6641 - val_accuracy: 0.8095

# %%
acc = model.history.history['accuracy']
val_acc = model.history.history['val_accuracy']
loss = model.history.history['loss']
val_loss = model.history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'b', label= 'Training accuracy')
plt.plot(epochs, val_acc, 'r', label= 'Validation accuracy')
plt.title('Training and Validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'b', label= 'Training loss')
plt.plot(epochs, val_loss, 'r', label= 'Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %%
TrainPredictions = model.predict(X_train)
TrainPredictions = np.argmax(TrainPredictions, axis=1)

# %%
train_labels = np.argmax(Y_train, axis=1)
conf = confusion_matrix(train_labels, TrainPredictions)

classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.Greens)
plt.title("Train Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 16.0, 'Predicted label')

# %%
from sklearn.metrics import accuracy_score
print('\nAccuracy: {:.4f}\n'.format(accuracy_score(train_labels, TrainPredictions)))
# Out:
# Accuracy: 1.0000

# %%
TestPredictions = model.predict(X_test)
TestPredictions = np.argmax(TestPredictions, axis=1)

# %%
test_labels = np.argmax(Y_test, axis=1)
conf = confusion_matrix(test_labels, TestPredictions)

classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.Greens)
plt.title("Test Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 16.0, 'Predicted label')

# %%
print('\nAccuracy: {:.4f}\n'.format(accuracy_score(test_labels, TestPredictions)))
# Out:
# Accuracy: 0.9200

# %%
print(X_test[1].shape)
x = np.expand_dims(X_test[1], axis=0)
print(x.shape)
Predictions = model.predict(x)
# Out:
# (64, 64, 3)
# (1, 64, 64, 3)

# %%
n=50
for i in range(n):
    #ax = plt.subplot(4, 5, i + 1)
    ax = plt.subplot()
    plt.imshow(data_test[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.show()

    Predictions = model.predict(np.expand_dims(X_test[i], axis=0))
    Predictions = np.argmax(Predictions, axis=1)
    if Predictions==0:
      print('NAO E UM GATO')
    else:
      print('E UM GATO')
#     input()
# Out:
# E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# NAO E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# NAO E UM GATO
# E UM GATO
# NAO E UM GATO
# E UM GATO
# NAO E UM GATO
# E UM GATO
# E UM GATO
# NAO E UM GATO
# NAO E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# NAO E UM GATO
# E UM GATO
# NAO E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# NAO E UM GATO
# NAO E UM GATO
# NAO E UM GATO
# E UM GATO
# NAO E UM GATO
# E UM GATO
# E UM GATO
# NAO E UM GATO
# E UM GATO
# NAO E UM GATO
# NAO E UM GATO
# NAO E UM GATO
# E UM GATO
# E UM GATO
# E UM GATO
# NAO E UM GATO
